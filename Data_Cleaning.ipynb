# %%
##

# %%
import pandas as pd

# %% [markdown]
# #### here we are adding the sample data set (excel file) to df

# %%
df = pd.read_excel("21_06_2024.xlsx")

# %% [markdown]
# checking if the data loaaded into the data frame correctly and check if any cleaning to be done for the data

# %%
df.head()
# Out:
#   Company Name:Divotechnologies Pvt Ltd\nRun Date & Time : 26/06/2024 11:41\nDAILY PERFORMANCE REPORT FOR DATE : 21/06/2024  \
# 0                                                Srl
# 1                                                  1
# 2                                                  2
# 3                                                  3
# 4                                                  4
#
#   Unnamed: 1    Unnamed: 2     Unnamed: 3 Unnamed: 4 Unnamed: 5 Unnamed: 6  \
# 0   Pay Code      Card No.  Employee Name                 Shift      Start
# 1         11  000000000011       P K RAVI        NaN        S01      09:00
# 2          2  000000000002       V BALAJI        NaN        S01      09:00
# 3          3  000000000003     M V PRASAD        NaN        S01      09:00
# 4          5  000000000005          DATTU        NaN        S01      09:00
#
#   Unnamed: 7 Unnamed: 8 Unnamed: 9 Unnamed: 10 Unnamed: 11 Unnamed: 12  \
# ...

# %%
print(df)
# Out:
#                                                    Unnamed: 1    Unnamed: 2  \
# Company Name:Divotechnologies Pvt Ltd\nRun Date...
# Srl                                                  Pay Code      Card No.
# 1                                                          11  000000000011
# 2                                                           2  000000000002
# 3                                                           3  000000000003
# 4                                                           5  000000000005
# 5                                                           6  000000000006
# 6                                                           7  000000000007
# 7                                                           8  000000000008
# 8                                                           9  000000000009
# 9                                                           1  000000000001
# 10                                                         10  000000000010
# ...

# %% [markdown]
# Now we see a lot of null columns and the first row has the names of columns. we will adjust the columns and make the dataframe more convinent and easy to use.

# %%
df[1:5]
# Out:
#   Company Name:Divotechnologies Pvt Ltd\nRun Date & Time : 26/06/2024 11:41\nDAILY PERFORMANCE REPORT FOR DATE : 21/06/2024  \
# 1                                                  1
# 2                                                  2
# 3                                                  3
# 4                                                  4
#
#   Unnamed: 1    Unnamed: 2  Unnamed: 3 Unnamed: 4 Unnamed: 5 Unnamed: 6  \
# 1         11  000000000011    P K RAVI        NaN        S01      09:00
# 2          2  000000000002    V BALAJI        NaN        S01      09:00
# 3          3  000000000003  M V PRASAD        NaN        S01      09:00
# 4          5  000000000005       DATTU        NaN        S01      09:00
#
#   Unnamed: 7 Unnamed: 8 Unnamed: 9 Unnamed: 10 Unnamed: 11 Unnamed: 12  \
# 1        NaN        NaN        NaN         NaN         NaN           A
# 2      09:42        NaN        NaN       18:12       08:32           P
# ...

# %%
df.iloc[2]
# Out:
# Company Name:Divotechnologies Pvt Ltd\nRun Date & Time : 26/06/2024 11:41\nDAILY PERFORMANCE REPORT FOR DATE : 21/06/2024               2
# Unnamed: 1                                                                                                                              2
# Unnamed: 2                                                                                                                   000000000002
# Unnamed: 3                                                                                                                       V BALAJI
# Unnamed: 4                                                                                                                            NaN
# Unnamed: 5                                                                                                                            S01
# Unnamed: 6                                                                                                                          09:00
# ...
